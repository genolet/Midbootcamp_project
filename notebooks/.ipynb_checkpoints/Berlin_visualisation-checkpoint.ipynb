# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages (0.11.1)
# Requirement already satisfied: fiona>=1.8 in /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.8.21)
# Requirement already satisfied: pyproj>=2.6.1.post1 in /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (3.3.1)
# Requirement already satisfied: packaging in /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (21.3)
# Requirement already satisfied: shapely<2,>=1.7 in /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.8.2)
# Requirement already satisfied: pandas>=1.0.0 in /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.4.2)
# Requirement already satisfied: six>=1.7 in /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: click-plugins>=1.0 in /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: attrs>=17 in /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: certifi in /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: setuptools in /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (61.2.0)
# Requirement already satisfied: click>=4.0 in /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (8.0.4)
# Requirement already satisfied: munch in /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: cligj>=0.5 in /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->geopandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->geopandas) (1.21.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages (from packaging->geopandas) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plz_shape_df = gpd.read_file('/Users/origenolet/Desktop/Ironhack/Week5/Mid-bootcamp-project/data/raw/plz-5stellig.shp.zip')
plz_shape_df.head()
# Out:
#      plz                            note  einwohner        qkm  \
# 0  81248                  81248 MÃ¼nchen        121   1.984763
# 1  60315  60315 Frankfurt am Main (FOUR)          0   0.017481
# 2  24988                  24988 Oeversee       3350  36.491463
# 3  93185         93185 Michelsneukirchen       1786  32.873844
# 4  93489                93489 Schorndorf       2622  38.597260
#
#                                             geometry
# 0  POLYGON ((11.39468 48.14729, 11.39490 48.14780...
# 1  POLYGON ((8.67254 50.11264, 8.67259 50.11264, ...
# 2  POLYGON ((9.36585 54.69994, 9.36683 54.70014, ...
# 3  POLYGON ((12.47666 49.13598, 12.47702 49.13637...
# 4  POLYGON ((12.54904 49.19318, 12.54953 49.19371...

# %%
plz_shape_df = plz_shape_df[["plz", "note", "geometry"]]
plz_shape_df
# Out:
#         plz                            note  \
# 0     81248                  81248 MÃ¼nchen
# 1     60315  60315 Frankfurt am Main (FOUR)
# 2     24988                  24988 Oeversee
# 3     93185         93185 Michelsneukirchen
# 4     93489                93489 Schorndorf
# ...     ...                             ...
# 8165  63874                  63874 Dammbach
# 8166  63856                63856 Bessenbach
# 8167  63869            63869 HeigenbrÃ¼cken
# 8168  75339         75339 HÃ¶fen an der Enz
# 8169  53881                53881 Euskirchen
#
#                                                geometry
# 0     POLYGON ((11.39468 48.14729, 11.39490 48.14780...
# 1     POLYGON ((8.67254 50.11264, 8.67259 50.11264, ...
# 2     POLYGON ((9.36585 54.69994, 9.36683 54.70014, ...
# 3     POLYGON ((12.47666 49.13598, 12.47702 49.13637...
# 4     POLYGON ((12.54904 49.19318, 12.54953 49.19371...
# ...                                                 ...
# 8165  POLYGON ((9.28704 49.86601, 9.28707 49.86608, ...
# 8166  POLYGON ((9.21845 49.96548, 9.22015 49.96586, ...
# 8167  POLYGON ((9.30293 50.04595, 9.30574 50.05000, ...
# 8168  POLYGON ((8.55002 48.79175, 8.55007 48.79177, ...
# 8169  POLYGON ((6.71045 50.68109, 6.71220 50.68290, ...
#
# [8170 rows x 3 columns]

# %%
plt.rcParams['figure.figsize'] = [16, 11]

# Get lat and lng of Germany's main cities. 
top_cities = {
    'Berlin': (13.404954, 52.520008), 
    'Cologne': (6.953101, 50.935173),
    'Düsseldorf': (6.782048, 51.227144),
    'Frankfurt am Main': (8.682127, 50.110924),
    'Hamburg': (9.993682, 53.551086),
    'Leipzig': (12.387772, 51.343479),
    'Munich': (11.576124, 48.137154),
    'Dortmund': (7.468554, 51.513400),
    'Stuttgart': (9.181332, 48.777128),
    'Nuremberg': (11.077438, 49.449820),
    'Hannover': (9.73322, 52.37052)
}

fig, ax = plt.subplots()

plz_shape_df.plot(ax=ax, color='orange', alpha=0.8)

# Plot cities. 
for c in top_cities.keys():
    # Plot city name.
    ax.text(
        x=top_cities[c][0], 
        # Add small shift to avoid overlap with point.
        y=top_cities[c][1] + 0.08, 
        s=c, 
        fontsize=12,
        ha='center', 
    )
    # Plot city location centroid.
    ax.plot(
        top_cities[c][0], 
        top_cities[c][1], 
        marker='o',
        c='black', 
        alpha=0.5
    )

ax.set(
    title='Germany', 
    aspect=1.3, 
    facecolor='lightblue'
);

# %%
plz_region_df = pd.read_csv(
    '/Users/origenolet/Desktop/Ironhack/Week5/Mid-bootcamp-project/data/raw/zuordnung_plz_ort.csv', 
    sep=',', 
    dtype={'plz': str})
plz_region_df.drop('osm_id', axis=1, inplace=True)
plz_region_df.head()
# Out:
#        ags     ort    plz                 landkreis           bundesland
# 0  8335001    Aach  78267        Landkreis Konstanz    Baden-Württemberg
# 1  7235001    Aach  54298  Landkreis Trier-Saarburg      Rheinland-Pfalz
# 2  5334002  Aachen  52062       Städteregion Aachen  Nordrhein-Westfalen
# 3  5334002  Aachen  52064       Städteregion Aachen  Nordrhein-Westfalen
# 4  5334002  Aachen  52066       Städteregion Aachen  Nordrhein-Westfalen

# %%
germany_df = pd.merge(
    left=plz_shape_df, 
    right=plz_region_df, 
    on='plz',
    how='inner'
)
germany_df.drop(['note'], axis=1, inplace=True)
germany_df.head()
# Out:
#      plz                                           geometry      ags  \
# 0  81248  POLYGON ((11.39468 48.14729, 11.39490 48.14780...  9162000
# 1  60315  POLYGON ((8.67254 50.11264, 8.67259 50.11264, ...  6412000
# 2  24988  POLYGON ((9.36585 54.69994, 9.36683 54.70014, ...  1059184
# 3  93185  POLYGON ((12.47666 49.13598, 12.47702 49.13637...  9372142
# 4  93489  POLYGON ((12.54904 49.19318, 12.54953 49.19371...  9372158
#
#                  ort                  landkreis          bundesland
# 0            München                        NaN              Bayern
# 1  Frankfurt am Main                        NaN              Hessen
# 2           Oeversee  Kreis Schleswig-Flensburg  Schleswig-Holstein
# 3  Michelsneukirchen             Landkreis Cham              Bayern
# 4         Schorndorf             Landkreis Cham              Bayern

# %%
berlin_df = germany_df.query('ort == "Berlin"')

# %%
berlin_neighbourhoods_df = gpd.read_file('/Users/origenolet/Desktop/Ironhack/Week5/Mid-bootcamp-project/data/raw/neighbourhoods.geojson')
berlin_neighbourhoods_df = berlin_neighbourhoods_df[~ berlin_neighbourhoods_df['neighbourhood_group'].isnull()]

berlin_neighbourhoods_df.head()
# Out:
#                                neighbourhood   neighbourhood_group  \
# 0             Blankenfelde/Niederschönhausen                Pankow
# 1                             Helmholtzplatz                Pankow
# 2                         Wiesbadener Straße  Charlottenburg-Wilm.
# 3  Schmöckwitz/Karolinenhof/Rauchfangswerder    Treptow - Köpenick
# 4                                 Müggelheim    Treptow - Köpenick
#
#                                             geometry
# 0  MULTIPOLYGON (((13.41191 52.61487, 13.41183 52...
# 1  MULTIPOLYGON (((13.41405 52.54929, 13.41422 52...
# 2  MULTIPOLYGON (((13.30748 52.46788, 13.30743 52...
# 3  MULTIPOLYGON (((13.70973 52.39630, 13.70926 52...
# 4  MULTIPOLYGON (((13.73762 52.40850, 13.73773 52...

# %%
fig, ax = plt.subplots()

berlin_df.plot(
    ax=ax, 
    alpha=0.2
)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots()

berlin_df.plot(
    ax=ax, 
    alpha=0.2
)

berlin_neighbourhoods_df.plot(
    ax=ax, 
    column='neighbourhood_group',
    categorical=True, 
    legend=True, 
    legend_kwds={'title': 'Neighbourhood', 'loc': 'upper right'},
    color='whitesmoke',
    edgecolor='gainsboro'
)

ax.set(
    title='Berlin Neighbourhoods', 
    aspect=1.3
);
# Out:
# /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages/geopandas/plotting.py:656: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   warnings.warn(

# %%
listings = pd.read_csv('/Users/origenolet/Desktop/Ironhack/Week5/Mid-bootcamp-project/data/clean/listings_clean.csv')
display(listings.head())
listings.columns
print(listings.info())
# Out:
#                    id          neighbourhood                  district  \
# 0            39971294  nördliche Luisenstadt  Friedrichshain-Kreuzberg
# 1            17580693            Parkviertel                     Mitte
# 2  579471587567149993              Friedenau    Tempelhof - Schöneberg
# 3            17497917         Alexanderplatz                     Mitte
# 4             9924899   Tempelhofer Vorstadt  Friedrichshain-Kreuzberg
#
#                  property_type        room_type  accommodates  n_bathrooms  \
# 0           Entire rental unit  Entire home/apt             2          1.0
# 1        Private room in condo     Private room             1          0.0
# 2           Entire rental unit  Entire home/apt             2          1.0
# 3           Entire rental unit  Entire home/apt             2          1.0
# 4  Private room in rental unit     Private room             1          0.0
#
#    bedrooms  beds  price  ...  kitchen  parking  balcony  bbq  washer  \
# 0       1.0   1.0   50.0  ...        1        1        0    0       1
# 1       1.0   1.0   42.0  ...        0        0        0    0       0
# 2       1.0   2.0   52.0  ...        1        0        0    0       1
# 3       1.0   1.0  106.0  ...        1        1        1    0       1
# 4       1.0   1.0   39.0  ...        1        0        0    0       0
#
#    host_email  host_phone  host_work_email  longitude   latitude
# 0           1           1                1  13.415730  52.501680
# 1           1           1                0  13.355150  52.561510
# 2           1           1                0  13.336424  52.477266
# 3           1           1                1  13.410120  52.524380
# 4           1           1                0  13.417120  52.490870
#
# [5 rows x 21 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14711 entries, 0 to 14710
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               14711 non-null  int64
#  1   neighbourhood    14711 non-null  object
#  2   district         14711 non-null  object
#  3   property_type    14711 non-null  object
#  4   room_type        14711 non-null  object
#  5   accommodates     14711 non-null  int64
#  6   n_bathrooms      14711 non-null  float64
#  7   bedrooms         14711 non-null  float64
#  8   beds             14711 non-null  float64
#  9   price            14711 non-null  float64
#  10  wifi             14711 non-null  int64
#  11  kitchen          14711 non-null  int64
#  12  parking          14711 non-null  int64
#  13  balcony          14711 non-null  int64
#  14  bbq              14711 non-null  int64
#  15  washer           14711 non-null  int64
#  16  host_email       14711 non-null  int64
#  17  host_phone       14711 non-null  int64
#  18  host_work_email  14711 non-null  int64
#  19  longitude        14711 non-null  float64
#  20  latitude         14711 non-null  float64
# dtypes: float64(6), int64(11), object(4)
# memory usage: 2.4+ MB
# None

# %%
plt.rcParams['figure.figsize'] = [10, 10]
fig, ax = plt.subplots()
berlin_df.plot(ax=ax, alpha=0.2, color = "grey")
berlin_neighbourhoods_df.plot(
    ax=ax, 
    column='neighbourhood_group',
    categorical=True, 
    legend=True, 
    legend_kwds={'title': 'Neighbourhood', 'loc': 'upper right'},
    color='whitesmoke',
    edgecolor='gainsboro'
)
for i in range(0,len(listings["longitude"])):
    ax.plot(list(listings["longitude"])[i],list(listings["latitude"])[i], marker='.',
        c='black', 
        alpha=0.3)

plt.savefig('../images/berlin.png', bbox_inches='tight')
# Out:
# /Users/origenolet/opt/anaconda3/lib/python3.9/site-packages/geopandas/plotting.py:656: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   warnings.warn(
